# %%
import pandas as pd

# %%
df2014 = pd.read_csv("../source/2014_Registered_Foreclosure_Properties.csv")
df2015 = pd.read_csv("../source/2015_Registered_Foreclosure_Properties.csv")
df2016 = pd.read_csv("../source/2016_Registered_Foreclosure_Properties.csv")
df2017 = pd.read_csv("../source/2017_Registered_Foreclosure_Properties.csv")
df2018 = pd.read_csv("../source/2018_Registered_Foreclosure_Properties.csv")
df2019 = pd.read_csv("../source/2019_Registered_Foreclosure_Properties.csv")
df2020 = pd.read_csv("../source/2020_Registered_Foreclosure_Properties.csv")
df2021 = pd.read_csv("../source/2021_Registered_Foreclosure_Properties.csv")
df2022 = pd.read_csv("../source/2022_Registered_Foreclosure_Properties.csv")

# %%
def remove_dups_and_non_residential(df):
    df = df[df['Property Type'] != 'Non-Residential']
    df = df[df.duplicated(subset=['Property Address']) != True]
    return df

# %%
def remove_dups_and_non_residential_2014(df):
    df = df[df['Property Type'] != 'Non-Residential']
    df = df[df.duplicated(subset=['Property Location']) != True]
    return df
df2014_adjusted = remove_dups_and_non_residential_2014(df2014)
print(len(df2014_adjusted), \
len(df2014))
df2014_adjusted.head()
# Out:
# 7334 7599
#           APN Registered Date  Property Type  \
# 0  4239001009      01/07/2014   Multi-Family
# 1  5006020018      05/12/2014  Single Family
# 2  5115024026      01/14/2014   Multi-Family
# 3  5114031027      04/10/2014   Multi-Family
# 4  6074021008      01/27/2014  Single Family
#
#                                    Property Location  Zip Code  \
# 0  709 S 5TH AVE\nLos Angeles, CA 90291\n(33.9954...     90291
# 1  5409 S 7TH AVE\nLos Angeles, CA 90043\n(33.992...     90043
# 2  4116 S MCKINLEY AVE\nLos Angeles, CA 90011\n(3...     90011
# 3  1217 E MARTIN LUTHER KING JR BLVD\nLOS ANGELES...     90011
# 4  127 W 111TH PL\nLos Angeles, CA 90061\n(33.933...     90061
#
#    Council District                             Lender Lender Contact  \
# 0                11                     DCB UNITED LLC   DENNIS ANGEL
# 1                 8                      ONE WEST BANK   LEAH COLLINS
# 2                 9  Provident Funding Associates L.P.    Carlos Sims
# 3                 9            NATIONSTAR MORTGAGE LLC   Paula Acosta
# 4                 8                        Freddie Mac  Evelyn Reeves
#
#   Lender Contact Phone Property Management Property Management Contact  \
# 0         818-881-0311                 NaN                         NaN
# 1         800-468-1743                 NaN                         NaN
# 2         626-485-8889                 NaN                         NaN
# 3         800-468-1743                 NaN                         NaN
# 4         323-299-7900                 NaN                         NaN
#
#   Property Management Address Property Contact Phone
# 0                         NaN                    NaN
# 1                         NaN                    NaN
# 2                         NaN                    NaN
# 3                         NaN                    NaN
# 4                         NaN                    NaN

# %%
df2015_adjusted = remove_dups_and_non_residential(df2015)
print(len(df2015_adjusted), \
len(df2015))
df2015_adjusted.head()
# Out:
# 7872 8255
#           APN Registered Date  Property Type  \
# 0  2004005034      10/04/2015  Single Family
# 1  2004010012      05/01/2015  Single Family
# 2  2004011022      28/01/2015  Single Family
# 3  2004012013      24/07/2015  Single Family
# 4  2004019004      13/04/2015  Single Family
#
#                             Property Address Property City Property State  \
# 0     8300 N SALE AVE\nLOS ANGELES, CA 93063   LOS ANGELES             CA
# 1   22400 W MALDEN ST\nLOS ANGELES, CA 93063   LOS ANGELES             CA
# 2     8400 N SALE AVE\nLOS ANGELES, CA 93063   LOS ANGELES             CA
# 3     8509 N SALE AVE\nLOS ANGELES, CA 93063   LOS ANGELES             CA
# 4  8432 N RUDNICK AVE\nLOS ANGELES, CA 93063   LOS ANGELES             CA
#
#    Property Zip  Council District                                 Lender  \
# 0         93063                12                          Fay Servicing
# 1         93063                12                  Wells Fargo Bank N.A.
# 2         93063                12                             NationStar
# 3         93063                12                                 Celink
# 4         93063                12  Federal National Mortgage Association
#
#    Lender Contact Lender Contact Phone               Property Management  \
# 0  Tina McCluskey         800-468-1743                               NaN
# 1    Amy Whitcomb         877-617-5274        Lender Processing Services
# 2    Paula Acosta         972-315-8837                           MCS/687
# 3    Cory Daggett         866-654-0020  Connie Renteria /  Five Brothers
# 4         N/A N/a         800-732-6643                      EDWARD ZUBIA
#
#   Property Management Contact  \
# 0                         NaN
# 1               Jonathon Holt
# 2    MCS Advantage Conveyance
# 3             Connie Renteria
# 4                EDWARD ZUBIA
#
#                        Property Management Address Property Mgmt Contact Phone
# 0                                                                          NaN
# 1       1003  E Brier DR  San Bernardino CA 92408                 877-617-8274
# 2       1906   Irvine AVE  Newport Beach CA 92660                 949-642-4801
# 3         5228   Halifax RD  Temple City CA 91780                 626-453-0397
# 4  3540   WILSHIRE BLVD 1109 LOS ANGELES CA 90010                 213-804-7437

# %%
def remove_dups_and_non_residential_2016(df):
    df = df[df['PropertyType'] != 'Non-Residential']
    df = df[df.duplicated(subset=['PropertyAddress']) != True]
    return df
df2016_adjusted = remove_dups_and_non_residential_2016(df2016)
print(len(df2016_adjusted), \
len(df2016))
df2016_adjusted.head()
# Out:
# 6628 7638
#           APN RegisteredDate   PropertyType  \
# 0  2601071034     01/02/2016  Single Family
# 1  5570001008     01/07/2016  Single Family
# 2  6119024008     11/07/2016  Single Family
# 3  2631026015     12/14/2016  Single Family
# 4  2254027011     11/23/2016  Single Family
#
#                                      PropertyAddress PropertyCity  \
# 0  17725 W ORNA DR\nLOS ANGELES, CA 91344\n(34.29...  LOS ANGELES
# 1  2695 N LA CUESTA DR\nLOS ANGELES, CA 90046\n(3...  LOS ANGELES
# 2  841 W 148TH ST\nLOS ANGELES, CA 90247\n(33.898...  LOS ANGELES
# 3  11826 W SNELLING ST\nLOS ANGELES, CA 91352\n(3...  LOS ANGELES
# 4          17431 W EMILITA ST\nLOS ANGELES, CA 91316  LOS ANGELES
#
#   PropertyState  PropertyZip  CouncilDistrict  \
# 0            CA        91344               12
# 1            CA        90046                4
# 2            CA        90247               15
# 3            CA        91352                6
# 4            CA        91316                5
#
#                                             Lender        LenderContact  \
# 0  Wells Fargo Bank C/O Select Portfolio Servicing     Select Servicing
# 1                               JP Morgan Chase NA             Amy Lott
# 2                             Ditech Financial LLC  Property Department
# 3                            Wells Fargo Bank N.A.        Jonathon Holt
# 4                                 ARTHUR WEINSTOCK     ARTHUR WEINSTOCK
#
#   LenderContactPhone                                 PropertyManagement  \
# 0       888-349-8964                                                NaN
# 1       888-310-1506                               Safeguard Properties
# 2       800-468-1743  AFS c/o PRIORITY 1 PROPERTY PRESERVATION INC -...
# 3       877-617-5274                                                LPS
# 4       818-708-7272                                                NaN
#
#   PropertyManagementContact                       PropertyManagementAddress  \
# 0              Edward Zubia      3540   wilshire BLVD  Los Angeles CA 90010
# 1      Safeguard Properties  3540   WILSHIRE BLVD 1109 LOS ANGELES CA 90010
# 2              Bill Kleiser        2780   Dove Tail DR  San Marcos CA 92078
# 3             Jonathon Holt       1003  E Brier DR  San Bernardino CA 92408
# 4                       NaN                                             NaN
#
#   PropertyMgmtContactPhone
# 0             213-804-7437
# 1             800-852-8306
# 2             800-468-1743
# 3             281-404-7816
# 4                      NaN

# %%
df2017_adjusted = remove_dups_and_non_residential(df2017)
print(len(df2017_adjusted), \
len(df2017))
df2017_adjusted.head()
# Out:
# 1575 1754
#           APN Registered Date  Property Type          Property Address  \
# 0  5003028023      01/25/2017  Single Family            1710 W 56TH ST
# 1  5534011013      08/31/2017   Multi-Family          1200 N GORDON ST
# 2  2429004015      11/01/2017  Single Family  7241 W WOODROW WILSON DR
# 3  5052020009      12/27/2017  Single Family            2260 W 29TH ST
# 4  6013003020      04/10/2017  Single Family    7018 1/4 S VERMONT AVE
#
#   Property City Property State  Property Zip  Council District  \
# 0   LOS ANGELES             CA         90062                 8
# 1     HOLLYWOOD             CA         90038                13
# 2   LOS ANGELES             CA         90068                 4
# 3   LOS ANGELES             CA         90018                10
# 4   LOS ANGELES             CA         90044                 8
#
#                   Lender     Lender Contact Lender Contact Phone  \
# 0  Wells Fargo Bank N.A.      Jonathon Holt         877-617-5274
# 1    NPI Debt Fund I, LP        Daniel Bien         949-386-7536
# 2           D. Benz, LLC  Brad Hakala, Esq.         562-432-5023
# 3      Champion Mortgage  Jennifer Hathaway         972-894-2950
# 4            Danco, Inc.   Ronald Perlstein         310-842-8235
#
#   Property Management Property Management Contact  \
# 0                 MCS             Code Compliance
# 1                 NaN                         NaN
# 2                 NaN                         NaN
# 3                 NaN                         NaN
# 4                 NaN                         NaN
#
#                  Property Management Address Property Mgmt Contact Phone  \
# 0  350   Highland DR 100 Lewisville TX 75067                813-387-1100
# 1                                        NaN                         NaN
# 2                                        NaN                         NaN
# 3                                        NaN                         NaN
# 4                                        NaN                         NaN
#
#                Property on Map
# 0  POINT (-118.30723 33.99136)
# 1  POINT (-118.31997 34.09274)
# 2   POINT (-118.3503 34.12422)
# 3  POINT (-118.31658 34.02897)
# 4  POINT (-118.29132 33.97584)

# %%
df2018_adjusted = remove_dups_and_non_residential(df2018)
print(len(df2018_adjusted), \
len(df2018))
df2018_adjusted.head()
# Out:
# 2732 3112
#           APN Registered Date  Property Type     Property Address  \
# 0  6003016019      10/31/2018   Multi-Family       1217 W 60TH PL
# 1  2151015040      11/01/2018  Single Family  20519 W HATTERAS ST
# 2  5442030015      11/05/2018  Single Family      2801 N MARSH ST
# 3  5015020012      01/17/2018   Multi-Family       2071 W 52ND ST
# 4  7416002028      01/05/2018  Single Family    649 N FRIGATE AVE
#
#   Property City Property State  Property Zip  Council District  \
# 0   LOS ANGELES             CA       90044.0                 9
# 1   LOS ANGELES             CA       91367.0                 3
# 2   LOS ANGELES             CA       90039.0                13
# 3   LOS ANGELES             CA       90062.0                 8
# 4   LOS ANGELES             CA       90744.0                15
#
#                                   Lender Lender Contact Lender Contact Phone  \
# 0                   JCAP Financial Group  Donna Cornejo         714-278-4202
# 1  Digestive Disease Research Foundation   Neil Gitnick         818-921-2455
# 2         Allstar Financial Services Inc     sumana sur         818-346-7827
# 3                     JP Morgan Chase NA       Amy Lott         888-310-1506
# 4                 BSI Financial Services    Ken Bodamer         800-327-7861
#
#     Property Management Property Management Contact  \
# 0                   NaN                         NaN
# 1                   NaN                         NaN
# 2                   NaN                         NaN
# 3  Safeguard Properties        Safeguard Properties
# 4                   NaN                         NaN
#
#                       Property Management Address  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3  3540   WILSHIRE BLVD 1109 LOS ANGELES CA 90010
# 4                                             NaN
#
#   Property Management Contact Phone  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                      800-852-8306
# 4                               NaN
#
#                                      Property on Map
# 0  1217 W 60TH PL\nLOS ANGELES, CA 90044\n(33.985...
# 1  20519 W HATTERAS ST\nLOS ANGELES, CA 91367\n(3...
# 2  2801 N MARSH ST\nLOS ANGELES, CA 90039\n(34.10...
# 3  2071 W 52ND ST\nLOS ANGELES, CA 90062\n(33.995...
# 4  649 N FRIGATE AVE\nLOS ANGELES, CA 90744\n(33....

# %%
df2019_adjusted = remove_dups_and_non_residential(df2019)
print(len(df2019_adjusted), \
len(df2019))
df2019_adjusted.head()
# Out:
# 2843 3317
#           APN Registered Date       Property Type    Property Address  \
# 0  2004019019      10/28/2019       Single Family  8560 N RUDNICK AVE
# 1  2134029009      06/07/2019       Single Family  6452 N JUMILLA AVE
# 2  2163016017      11/05/2019       Single Family  19255 W REDWING ST
# 3  2378026016      04/10/2019  Vacant Residential   11258 W LAURIE DR
# 4  2376001011      10/28/2019       Single Family  4148 N SUNSWEPT DR
#
#   Property City Property State  Property Zip  Council District  \
# 0   LOS ANGELES             CA         93063                12
# 1   LOS ANGELES             CA         91367                 3
# 2   LOS ANGELES             CA         91356                 3
# 3   LOS ANGELES             CA         91604                 2
# 4   LOS ANGELES             CA         91604                 2
#
#                         Lender     Lender Contact Lender Contact Phone  \
# 0     PHH Mortgage Corporation   Marquita Bullock         888-820-6474
# 1    Residential First Capital    Stephen Solorio         949-783-7920
# 2  First National funding Corp  Michael Nikravesh         818-285-5626
# 3              Cal Pac Capital     Justin Johnson         949-383-4763
# 4              Aztec Financial       Chloe Allton         818-848-8960
#
#          Property Management Property Management Contact  \
# 0  Remedy Field Services Inc                 Agnes Mella
# 1                        NaN                         NaN
# 2                        NaN                         NaN
# 3                        NaN                         NaN
# 4            Aztec Financial                Chloe Allton
#
#                 Property Management Address Property Management Contact Phone  \
# 0       15615   Alton PKWY  IRVINE CA 92618                      888-540-4490
# 1                                       NaN                               NaN
# 2                                       NaN                               NaN
# 3                                       NaN                               NaN
# 4  2624  W MAGNOLIA  BLVD  BURBANK CA 91505                      818-848-8960
#
#    Longitude  Latitude                       Property on Map
# 0 -118.61291  34.22684           POINT (-118.61291 34.22684)
# 1 -118.56314  34.18823           POINT (-118.56314 34.18823)
# 2 -118.55295  34.17097           POINT (-118.55295 34.17097)
# 3 -118.37539  34.13644  POINT (-118.37539000000001 34.13644)
# 4 -118.40584  34.14129           POINT (-118.40584 34.14129)

# %%
df2020_adjusted = remove_dups_and_non_residential(df2020)
print(len(df2020_adjusted), \
len(df2020))
df2020_adjusted.head()
# Out:
# 2656 3005
#           APN Registered Date  Property Type       Property Address  \
# 0  2134029009      02/26/2020  Single Family     6452 N JUMILLA AVE
# 1  2161009016      04/08/2020  Single Family     5351 N YOLANDA AVE
# 2  2226029012      07/08/2020  Single Family     7430 N BALBOA BLVD
# 3  2260017041      01/08/2020  Single Family   5184 N MAGNOLIA BLVD
# 4  2286021032      09/01/2020  Single Family  3939 N HAYVENHURST DR
#
#   Property City Property State  Property Zip  Council District  \
# 0   LOS ANGELES             CA         91367                 3
# 1   LOS ANGELES             CA         91356                 3
# 2   LOS ANGELES             CA         91406                 6
# 3   LOS ANGELES             CA         91436                 5
# 4   LOS ANGELES             CA         91436                 5
#
#                            Lender      Lender Contact Lender Contact Phone  \
# 0                     Myers Trust         Myers Trust         818-845-4000
# 1                      Geraci LLP  Melissa Martorella         949-379-2600
# 2           K.A.R. Properties Inc     Richard Herrera         310-212-3056
# 3  Specialized Loan Servicing LLC             n/a n/a         800-842-7654
# 4              City National Bank         Joe Shapard         213-673-8158
#
#   Property Management Property Management Contact  \
# 0                 NaN                         NaN
# 1          LRES Corp.                Kathy Golden
# 2                 NaN                         NaN
# 3                 NaN                         NaN
# 4                 NaN                         NaN
#
#                        Property Management Address  \
# 0                                              NaN
# 1  765   The City Drive South  300 Orange CA 92868
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#   Property Management Contact Phone        lon       lat  \
# 0                               NaN -118.56314  34.18823
# 1                      800-434-6125 -118.54101  34.16797
# 2                               NaN -118.50090  34.20559
# 3                               NaN -118.48712  34.16464
# 4                               NaN -118.48566  34.14232
#
#                          Property on Map
# 0            POINT (-118.56314 34.18823)
# 1            POINT (-118.54101 34.16797)
# 2             POINT (-118.5009 34.20559)
# 3   POINT (-118.48711999999999 34.16464)
# 4  POINT (-118.48566 34.142320000000005)

# %%
def remove_dups_and_non_residential_2021(df):
    df = df[df['Property Type'] != 'Non-Residential']
    df = df[df.duplicated(subset=['PropertyAddress']) != True]
    return df
df2021_adjusted = remove_dups_and_non_residential_2021(df2021)
print(len(df2021_adjusted), \
len(df2021))
df2021_adjusted['Registered Date'] = df2021_adjusted['Registered Date'].apply(lambda x: x[:10])
df2021_adjusted
# Out:
# 1986 2134
#              APN Registered Date  Property Type     PropertyAddress  \
# 0     2340010012      12/28/2021  Single Family   12026 W CALIFA ST
# 1     6083002006      01/13/2021  Single Family    138 E LANZIT AVE
# 2     5014004009      01/07/2021   Multi-Family      4517 S 9TH AVE
# 3     5555007014      03/22/2021  Single Family    1376 N MILLER PL
# 4     5055010013      01/07/2021   Multi-Family  1352 1/2 W 29TH ST
# ...          ...             ...            ...                 ...
# 2127  6035025021      12/06/2021  Single Family      1838 W 84TH PL
# 2128  2727003022      04/09/2021  Single Family  22500 W NEEDLES ST
# 2129  2109018006      01/08/2021  Single Family    21025 W STAGG ST
# 2130  4204020116      01/13/2021  Single Family      5829  BOWCROFT
# 2132  6023012011      01/08/2021  Single Family      1000 E 74TH ST
#
#      PropertyCity PropertyState  PropertyZip  CouncilDistrict  \
# 0     LOS ANGELES            CA        91607                2
# 1     LOS ANGELES            CA        90061               15
# 2     LOS ANGELES            CA        90043                8
# 3       HOLLYWOOD            CA        90069                4
# 4     LOS ANGELES            CA        90007                9
# ...           ...           ...          ...              ...
# 2127  LOS ANGELES            CA        90047                8
# 2128  LOS ANGELES            CA        91311               12
# 2129  LOS ANGELES            CA        93063                3
# 2130  LOS ANGELES            CA        90016               10
# 2132  LOS ANGELES            CA        90001                9
#
#                                                  Lender  \
# 0                                    Robert Khodorovsky
# 1                                                Celink
# 2                                           DANCO, INC.
# 3                    Commercial Group International Inc
# 4                                           DANCO, INC.
# ...                                                 ...
# 2127                       United Asset Management, LLC
# 2128                                The Moonwalkers LLC
# 2129  Specialized Loan Servicing LLC C/O Computersha...
# 2130                                             Celink
# 2132                         Select Portfolio Servicing
#
#                    LenderContact LenderContactPhone  \
# 0             Robert Khodorovsky       818-486-9736
# 1                   Daniel Stack       866-727-4303
# 2               RONALD PERLSTEIN       310-842-8234
# 3                  Pamela Becker       310-804-3873
# 4               RONALD PERLSTEIN       310-842-8234
# ...                          ...                ...
# 2127              Claudio Chavez       714-849-5940
# 2128            Sarvar Abdullaev       818-419-4746
# 2129    Computershare Management       720-241-7375
# 2130                Daniel Stack       866-727-4303
# 2132  Select Portfolio Servicing       888-349-8964
#
#                      PropertyManagement PropertyManagementContact  \
# 0                                   NaN                       NaN
# 1        J & J BOARD- UPS/FIVE BROTHERS              JAVIER ORTIZ
# 2                                   NaN                       NaN
# 3                                   NaN                       NaN
# 4                                   NaN                       NaN
# ...                                 ...                       ...
# 2127                                NaN                       NaN
# 2128  Solid Foundation Properties, LLC.           Compliance Team
# 2129             First Team Real Estate                 Eddy Leon
# 2130     J & J BOARD- UPS/FIVE BROTHERS              JAVIER ORTIZ
# 2132                       Edward Zubia             edaward zubia
#
#                        PropertyManagementAddress PropertyMgmtContactPhone  \
# 0                                            NaN                      NaN
# 1              475  S Rall AVE  Bassett CA 91746             626-290-9017
# 2                                            NaN                      NaN
# 3                                            NaN                      NaN
# 4                                            NaN                      NaN
# ...                                          ...                      ...
# 2127                                         NaN                      NaN
# 2128      2690   Cobb PKWY A5379 SMYRNA GA 30080             333-205-7447
# 2129       20234   State ROAD  Cerritos CA 90703             562-461-1200
# 2130           475  S Rall AVE  Bassett CA 91746             626-290-9017
# 2132  3540   wilshire BLVD  Los Angeles CA 90010             213-804-7437
#
#             lon       lat              Property on map
# 0    -118.39509  34.17721  POINT (-118.39509 34.17721)
# 1    -118.27255  33.92961  POINT (-118.27255 33.92961)
# 2    -118.32704  34.00219  POINT (-118.32704 34.00219)
# 3    -118.37660  34.09547   POINT (-118.3766 34.09547)
# 4    -118.29052  34.02816  POINT (-118.29052 34.02816)
# ...         ...       ...                          ...
# 2127 -118.31044  33.96167  POINT (-118.31044 33.96167)
# 2128 -118.61708  34.24659  POINT (-118.61708 34.24659)
# 2129 -118.59170  34.21119   POINT (-118.5917 34.21119)
# 2130 -118.37361  34.02028  POINT (-118.37361 34.02028)
# 2132 -118.25757  33.97289  POINT (-118.25757 33.97289)
#
# [1986 rows x 18 columns]

# %%
df2022_adjusted = remove_dups_and_non_residential(df2022)
print(len(df2022_adjusted), \
len(df2022))
df2022_adjusted.head()
# Out:
# 2247 2375
#           APN Registered Date       Property Type       Property Address  \
# 0  2042008014      05/16/2022       Single Family    22858 W DOLOROSA ST
# 1  2172033051      01/24/2022       Single Family  21221 W MULHOLLAND DR
# 2  2276029020      06/17/2022       Single Family      14606 W SUTTON ST
# 3  2542008007      01/24/2022  Vacant Residential   10340 N CLYBOURN AVE
# 4  4019003018      02/01/2022       Single Family         4227 W 58TH PL
#
#   Property City Property State  Property Zip  Council District  \
# 0   LOS ANGELES             CA         91367                 3
# 1   LOS ANGELES             CA         91364                 3
# 2   LOS ANGELES             CA         91403                 4
# 3   LOS ANGELES             CA         91040                 7
# 4   LOS ANGELES             CA         90043                 8
#
#                          Lender    Lender Contact Lender Contact Phone  \
# 0  LBC Capital Income Fund, LLC  Kirill Pilipenko         818-761-7234
# 1    4 Towers Development, Inc.        Avi Raceah         818-591-4913
# 2                  andre berger       Stacy Sokol         310-266-8353
# 3                    TJ Schramm        TJ Schramm         936-689-3315
# 4    Reverse Mortgage Solutions   Shelly Martinez         281-404-7962
#
#          Property Management Property Management Contact  \
# 0                        NaN                         NaN
# 1                        NaN                         NaN
# 2                        NaN                         NaN
# 3                        NaN                         NaN
# 4  Guardian Asset Management                 Gina Butler
#
#              Property Management Address Property Mgmt Contact Phone  \
# 0                                    NaN                         NaN
# 1                                    NaN                         NaN
# 2                                    NaN                         NaN
# 3                                    NaN                         NaN
# 4  2021   Hartel AVE  Levittown PA 19057                888-872-9094
#
#          lon       lat              Property on map
# 0 -118.62539  34.16994  POINT (-118.62539 34.16994)
# 1 -118.59516  34.14367  POINT (-118.59516 34.14367)
# 2 -118.45269  34.14756  POINT (-118.45269 34.14756)
# 3 -118.37082  34.25830   POINT (-118.37082 34.2583)
# 4 -118.34874  33.98810   POINT (-118.34874 33.9881)
