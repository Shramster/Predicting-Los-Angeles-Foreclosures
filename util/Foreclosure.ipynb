# %%
import numpy as np
import pandas as pd
import sklearn
import matplotlib.pyplot as plt

def getRidOfDays(df):
    X = df
    X['Registered Date'] = df['Registered Date'].replace(to_replace="\/\d\d\/", regex=True, value="/")
    return X

# It's dd/mm/yyyy than mm/dd/yyyy for 2015
def getRidOfDays2015(df):
    X = df
    X['Registered Date'] = df['Registered Date'].replace(to_replace="^[0-9][0-9]\/", regex=True, value="")
    return X

# Remove the ".0" for 2018's Zip code
def removeDotZero(df):
    X = df
    return X

# Remove "12:00:00 AM" for 2021
def removeTime2021(df):
    X = df
    X['Registered Date'] = df['Registered Date'].replace(to_replace="\ \d\d\:\d\d\:\d\d\ [A-Z][A-Z]", regex=True, value="")
    return X

# %%
df2014 = pd.read_csv("../source/2014_Registered_Foreclosure_Properties.csv")
df2015 = pd.read_csv("../source/2015_Registered_Foreclosure_Properties.csv")

df2016 = pd.read_csv("../source/2016_Registered_Foreclosure_Properties.csv").rename(columns= {"RegisteredDate":"Registered Date"})

df2017 = pd.read_csv("../source/2017_Registered_Foreclosure_Properties.csv")

df2018 = pd.read_csv("../source/2018_Registered_Foreclosure_Properties.csv")


df2019 = pd.read_csv("../source/2019_Registered_Foreclosure_Properties.csv")

df2020 = pd.read_csv("../source/2020_Registered_Foreclosure_Properties.csv")

df2021 = pd.read_csv("../source/2021_Registered_Foreclosure_Properties.csv")


df2022 = pd.read_csv("../source/2022_Registered_Foreclosure_Properties.csv")
df2014
# Out:
#              APN Registered Date  Property Type  \
# 0     4239001009      01/07/2014   Multi-Family
# 1     5006020018      05/12/2014  Single Family
# 2     5115024026      01/14/2014   Multi-Family
# 3     5114031027      04/10/2014   Multi-Family
# 4     6074021008      01/27/2014  Single Family
# ...          ...             ...            ...
# 7594  5690023006      01/30/2014  Single Family
# 7595  6031019017      09/17/2014   Multi-Family
# 7596  5063007085      11/25/2014  Single Family
# 7597  6075004009      09/24/2014  Single Family
# 7598  2755002069      07/22/2014  Single Family
#
#                                       Property Location  Zip Code  \
# 0     709 S 5TH AVE\nLos Angeles, CA 90291\n(33.9954...     90291
# 1     5409 S 7TH AVE\nLos Angeles, CA 90043\n(33.992...     90043
# 2     4116 S MCKINLEY AVE\nLos Angeles, CA 90011\n(3...     90011
# 3     1217 E MARTIN LUTHER KING JR BLVD\nLOS ANGELES...     90011
# ...

# %%
def remove_dups_and_non_residential(df):
    df = df[df['Property Type'] != 'Non-Residential']
    df = df[df.duplicated(subset=['Property Address']) != True]
    return df

def remove_dups_and_non_residential_2014(df):
    df = df[df['Property Type'] != 'Non-Residential']
    df = df[df.duplicated(subset=['Property Location']) != True]
    return df
df2014 = remove_dups_and_non_residential_2014(df2014)

df2015 = remove_dups_and_non_residential(df2015)

def remove_dups_and_non_residential_2016(df):
    df = df[df['PropertyType'] != 'Non-Residential']
    df = df[df.duplicated(subset=['PropertyAddress']) != True]
    return df
df2016 = remove_dups_and_non_residential_2016(df2016)

df2017 = remove_dups_and_non_residential(df2017)

df2018 = remove_dups_and_non_residential(df2018)

df2019 = remove_dups_and_non_residential(df2019)

df2020 = remove_dups_and_non_residential(df2020)

def remove_dups_and_non_residential_2021(df):
    df = df[df['Property Type'] != 'Non-Residential']
    df = df[df.duplicated(subset=['PropertyAddress']) != True]
    return df
df2021 = remove_dups_and_non_residential_2021(df2021)

df2022 = remove_dups_and_non_residential(df2022)

# %%
df2014 = getRidOfDays(df2014)

df2015 = getRidOfDays2015(df2015)

df2016 = getRidOfDays(df2016)

df2017 = getRidOfDays(df2017)

df2018 = getRidOfDays(df2018)

df2019 = getRidOfDays(df2019)

df2020 = getRidOfDays(df2020)

df2021 = getRidOfDays(df2021)
df2021 = removeTime2021(df2021)

df2022 = getRidOfDays(df2022)

# %%
df2014
# Out:
#              APN Registered Date  Property Type  \
# 0     4239001009         01/2014   Multi-Family
# 1     5006020018         05/2014  Single Family
# 2     5115024026         01/2014   Multi-Family
# 3     5114031027         04/2014   Multi-Family
# 4     6074021008         01/2014  Single Family
# ...          ...             ...            ...
# 7594  5690023006         01/2014  Single Family
# 7595  6031019017         09/2014   Multi-Family
# 7596  5063007085         11/2014  Single Family
# 7597  6075004009         09/2014  Single Family
# 7598  2755002069         07/2014  Single Family
#
#                                       Property Location  Zip Code  \
# 0     709 S 5TH AVE\nLos Angeles, CA 90291\n(33.9954...     90291
# 1     5409 S 7TH AVE\nLos Angeles, CA 90043\n(33.992...     90043
# 2     4116 S MCKINLEY AVE\nLos Angeles, CA 90011\n(3...     90011
# 3     1217 E MARTIN LUTHER KING JR BLVD\nLOS ANGELES...     90011
# ...

# %%
df2015
# Out:
#              APN Registered Date  Property Type  \
# 0     2004005034         04/2015  Single Family
# 1     2004010012         01/2015  Single Family
# 2     2004011022         01/2015  Single Family
# 3     2004012013         07/2015  Single Family
# 4     2004019004         04/2015  Single Family
# ...          ...             ...            ...
# 8250  5478009078         01/2015  Single Family
# 8251  7415016021         01/2015  Single Family
# 8252  2618009004         06/2015  Single Family
# 8253  5436029018         01/2015   Multi-Family
# 8254  5456005028         01/2015  Single Family
#
#                                        Property Address Property City  \
# 0                8300 N SALE AVE\nLOS ANGELES, CA 93063   LOS ANGELES
# 1              22400 W MALDEN ST\nLOS ANGELES, CA 93063   LOS ANGELES
# 2                8400 N SALE AVE\nLOS ANGELES, CA 93063   LOS ANGELES
# 3                8509 N SALE AVE\nLOS ANGELES, CA 93063   LOS ANGELES
# ...

# %%
df2016
# Out:
#              APN Registered Date   PropertyType  \
# 0     2601071034         01/2016  Single Family
# 1     5570001008         01/2016  Single Family
# 2     6119024008         11/2016  Single Family
# 3     2631026015         12/2016  Single Family
# 4     2254027011         11/2016  Single Family
# ...          ...             ...            ...
# 7632  5170003010         08/2016   Multi-Family
# 7634  5037003006         01/2016  Single Family
# 7635  2348008053         01/2016   Multi-Family
# 7636  2226021019         03/2016  Single Family
# 7637  7415012040         01/2016   Multi-Family
#
#                                         PropertyAddress     PropertyCity  \
# 0     17725 W ORNA DR\nLOS ANGELES, CA 91344\n(34.29...      LOS ANGELES
# 1     2695 N LA CUESTA DR\nLOS ANGELES, CA 90046\n(3...      LOS ANGELES
# 2     841 W 148TH ST\nLOS ANGELES, CA 90247\n(33.898...      LOS ANGELES
# 3     11826 W SNELLING ST\nLOS ANGELES, CA 91352\n(3...      LOS ANGELES
# ...

# %%
df2017
# Out:
#              APN Registered Date  Property Type           Property Address  \
# 0     5003028023         01/2017  Single Family             1710 W 56TH ST
# 1     5534011013         08/2017   Multi-Family           1200 N GORDON ST
# 2     2429004015         11/2017  Single Family   7241 W WOODROW WILSON DR
# 3     5052020009         12/2017  Single Family             2260 W 29TH ST
# 4     6013003020         04/2017  Single Family     7018 1/4 S VERMONT AVE
# ...          ...             ...            ...                        ...
# 1745  5690003021         01/2017  Single Family      1307 W LINDA ROSA AVE
# 1750  2114018099         01/2017  Single Family           20134 W LEADWELL
# 1751  7416023018         01/2017  Single Family          931 N NEPTUNE AVE
# 1752  5094023021         01/2017   Multi-Family  3078 W JAMES M. WOOD BLVD
# 1753  7445002012         10/2017  Single Family           1300 N MEYLER ST
#
#      Property City Property State  Property Zip  Council District  \
# ...

# %%
df2018
# Out:
#              APN Registered Date  Property Type       Property Address  \
# 0     6003016019         10/2018   Multi-Family         1217 W 60TH PL
# 1     2151015040         11/2018  Single Family    20519 W HATTERAS ST
# 2     5442030015         11/2018  Single Family        2801 N MARSH ST
# 3     5015020012         01/2018   Multi-Family         2071 W 52ND ST
# 4     7416002028         01/2018  Single Family      649 N FRIGATE AVE
# ...          ...             ...            ...                    ...
# 3107  2624006027         01/2018  Single Family    9945 N TAMARACK AVE
# 3108  4383006022         01/2018  Single Family      9847 W PORTOLA DR
# 3109  2761013009         01/2018  Single Family  9749 N QUAKERTOWN AVE
# 3110  2542019010         01/2018  Single Family      9651 N SUNLAND PL
# 3111  4384018005         08/2018  Single Family       9736 W YOAKUM DR
#
#      Property City Property State  Property Zip  Council District  \
# ...

# %%
df2019
# Out:
#              APN Registered Date       Property Type    Property Address  \
# 0     2004019019         10/2019       Single Family  8560 N RUDNICK AVE
# 1     2134029009         06/2019       Single Family  6452 N JUMILLA AVE
# 2     2163016017         11/2019       Single Family  19255 W REDWING ST
# 3     2378026016         04/2019  Vacant Residential   11258 W LAURIE DR
# 4     2376001011         10/2019       Single Family  4148 N SUNSWEPT DR
# ...          ...             ...                 ...                 ...
# 3310  7406022020         05/2019       Single Family  1837 N AVALON BLVD
# 3311  2126002008         01/2019       Single Family   7125 N GEYSER AVE
# 3312  5109025013         10/2019        Multi-Family   312 1/4 E 52ND ST
# 3313  2254017035         10/2019       Single Family  17336 W COLLINS ST
# 3314  4352011010         04/2019       Single Family  1423 N SCHUYLER RD
#
#      Property City Property State  Property Zip  Council District  \
# ...

# %%
df2020
# Out:
#              APN Registered Date  Property Type       Property Address  \
# 0     2134029009         02/2020  Single Family     6452 N JUMILLA AVE
# 1     2161009016         04/2020  Single Family     5351 N YOLANDA AVE
# 2     2226029012         07/2020  Single Family     7430 N BALBOA BLVD
# 3     2260017041         01/2020  Single Family   5184 N MAGNOLIA BLVD
# 4     2286021032         09/2020  Single Family  3939 N HAYVENHURST DR
# ...          ...             ...            ...                    ...
# 3000  2625033002         01/2020  Single Family    13321 W BRANFORD ST
# 3001  4019006027         01/2020  Single Family         4235 W 59TH ST
# 3002  5054011011         06/2020  Single Family    2633 S VAN BUREN PL
# 3003  2613024045         11/2020  Single Family         14337 W FOX ST
# 3004  6055015041         01/2020  Single Family         1514 W 99TH ST
#
#      Property City Property State  Property Zip  Council District  \
# ...

# %%
df2021
# Out:
#              APN Registered Date  Property Type     PropertyAddress  \
# 0     2340010012         12/2021  Single Family   12026 W CALIFA ST
# 1     6083002006         01/2021  Single Family    138 E LANZIT AVE
# 2     5014004009         01/2021   Multi-Family      4517 S 9TH AVE
# 3     5555007014         03/2021  Single Family    1376 N MILLER PL
# 4     5055010013         01/2021   Multi-Family  1352 1/2 W 29TH ST
# ...          ...             ...            ...                 ...
# 2127  6035025021         12/2021  Single Family      1838 W 84TH PL
# 2128  2727003022         04/2021  Single Family  22500 W NEEDLES ST
# 2129  2109018006         01/2021  Single Family    21025 W STAGG ST
# 2130  4204020116         01/2021  Single Family      5829  BOWCROFT
# 2132  6023012011         01/2021  Single Family      1000 E 74TH ST
#
#      PropertyCity PropertyState  PropertyZip  CouncilDistrict  \
# 0     LOS ANGELES            CA        91607                2
# ...

# %%
df2022
# Out:
#              APN Registered Date       Property Type  \
# 0     2042008014         05/2022       Single Family
# 1     2172033051         01/2022       Single Family
# 2     2276029020         06/2022       Single Family
# 3     2542008007         01/2022  Vacant Residential
# 4     4019003018         02/2022       Single Family
# ...          ...             ...                 ...
# 2370  2123021034         06/2022       Single Family
# 2371  4382022001         03/2022       Single Family
# 2372  4106001015         08/2022       Single Family
# 2373  6033012040         04/2022       Single Family
# 2374  2606011026         09/2022       Single Family
#
#                Property Address Property City Property State  Property Zip  \
# 0           22858 W DOLOROSA ST   LOS ANGELES             CA         91367
# 1         21221 W MULHOLLAND DR   LOS ANGELES             CA         91364
# 2             14606 W SUTTON ST   LOS ANGELES             CA         91403
# ...

# %%
result = pd.concat([df2014['Registered Date'], df2015['Registered Date'], df2016['Registered Date'], df2017['Registered Date'], df2018['Registered Date'], df2019['Registered Date'], df2020['Registered Date'], df2021['Registered Date'], df2022['Registered Date']], ignore_index=True)
result.to_csv("../source/Combined_Foreclosures.csv")

result
# Out:
# 0        01/2014
# 1        05/2014
# 2        01/2014
# 3        04/2014
# 4        01/2014
#           ...
# 35868    06/2022
# 35869    03/2022
# 35870    08/2022
# 35871    04/2022
# 35872    09/2022
# Name: Registered Date, Length: 35873, dtype: object
